# %%
import xlrd
import pandas as pd
from pandas import DataFrame
pd.set_option('display.max_rows', 3000)

import xlrd,xlwt
from xlutils.copy import copy

import openpyxl

import os

# %%
def load_data(file_name):
    names = ['items', 'unit', 'price']
    
    wb = xlrd.open_workbook(file_name)
    # obtain all the sheet in the workbook
    sheets_name = wb.sheet_names()
    # print(sheets)
    
    # too less info, omit
    if len(sheets_name) <= 5:
        return
 
    # iterator sheets without the total sheet
    df_all = DataFrame()
    for i in range(len(sheets_name)-1):
    # skiprows=2 omit tow
        df = pd.read_excel(file_name, names = names, sheet_name=i, skiprows=2, 
                       skipfooter = 3, usecols= [0,1,3])
        df_all= df_all.append(df)
        
    
    # print(df_all)

    # delete Nan value and reset index
    df_all = df_all.dropna()
    df_all = df_all.reset_index(drop=True)
    
    # print(df_all)
    
    df_total = pd.read_excel(file_name, 
                             # usecols: use which cols as input
                             # skiprows = 1, jump title and set header to None
                   sheet_name=len(sheets_name)-1,skiprows=1, header = None, names = names, usecols = "A:C")
    # print(df_total)

    # contact active and old database together
    frames = [df_all, df_total]
    results = pd.concat(frames)
    
    # be used for debug
    print(results)
    
    # according to prices, sort value
    results.sort_values(axis=0, ascending=False, inplace=True, 
           kind='quicksort', by=['price'])
    # print(results)
    #based on item and unit to dropout duplicated vlaue
    results.drop_duplicates(['items', 'unit'], keep = 'first', inplace = True)
    
    # reset index
    results = results.reset_index(drop=True)
    
    # print(results)
    
    workbook = openpyxl.load_workbook(file_name)
    # get the name of all workbook
#     name_list = workbook.sheet_names()
    # print(name_list)

    # leave 2,3,4 page as template
    for step, i in enumerate(sheets_name):
        if step == 0 or step == len(sheets_name)-3 or step == 1:
            continue
        
#         print(i)

        # delete workbook with sheet name
        del workbook[i]

    # print(workbook.get_sheet_names())
    workbook._active_sheet_index = 0
    workbook.save(file_name)
    
    # save new data into original excel sheet
    with pd.ExcelWriter(file_name, engine="openpyxl", mode = 'a') as writer:
        # write results to that file_name, name this name in: sheet_name
        # without index
        results.to_excel(writer, sheet_name = sheets_name[len(sheets_name)-1], header = ['品名', '单位', '单价'], index = False)
        writer.save()

# %%
if __name__ == '__main__':

    static_dir = "/home/user/Xizhuquan_business/2021.3/"  
    
    any_unrecorder = True
    dir = static_dir
    
    while any_unrecorder:
  
        filename_excel = []
        folder_name = []
        any_unrecorder = False

        for root, dirs, files in os.walk(dir):
            for file in files:

                if not file.endswith('.xlsx'):
                    continue
                # print(os.path.join(root,file))
                filename_excel.append(os.path.join(root,file))

        # print(filename_excel)

        for file in filename_excel:
            print("I m processing ", file)
            load_data(file)
            
        if len(folder_name) != 0:
            temp_folder_name = folder_name.pop(0)
            dir = static_dir + str(temp_folder_name)
            any_unrecorder = True
            
    print("processing finished")
# Out:
# I m processing  /home/user/Xizhuquan_business/2021.3/群力远大.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/安埠街441号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/佳木斯司凡雨.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/老菜馆.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/嘉禾名粥.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/建国街279号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/五常拉林.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/广西南宁.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/水灵灵超市.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/人防.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/百姓人家.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/刘才干调.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/杜红.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/曲线街41号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/光芒街8号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/赵仁伟新232车.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/大庆.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/二楼海鲜.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/120.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/2999.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/772.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/293.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/白玛拉姆.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/去茶去.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/歌剧院.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/大芥末.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/男帅哥中央大街232号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/209.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/松雷.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/红霞街49号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/吉林松原江南.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/锅烙.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/尚志胡同.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/235双城龙虾小王子.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/蚝探长.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/北海贝.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/8Y7N1.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/美娜.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/会所男.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/小昆仑.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/阿城大福鼎.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/68E8.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/大美丽.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/会所A.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/A1RP57.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/五常松之日.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/安道街50号.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/930.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/8E3G2.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/五常四季.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/阿城金忠鑫.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/道里十四道街烤肉.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/双城.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/2019会所.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/五常御海棠分店.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/哈西烤肉.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/320车.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/金牌锅烙妈妈菜烤鱼.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/266友谊大厦.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/551车.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/人大.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/大艳.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/低频报货/小资太太.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/三八.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/广东省日出东方.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/23455.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/6240.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/6377.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/希尔顿.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/温州老乡饭庄.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/五站.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/C72.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/福旺楼新人扈炳仲.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/311车.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/哈西仁义涵咖啡 .xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/郡宴海鲜.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/状元楼.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/革新街.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/五常御海棠.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/温州小酒馆.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/轩庆小区.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/建盈商贸.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/8B883.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/兄弟餐馆.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/风味.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/哈西.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/西九道.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/南兴街.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/通江烧烤.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/湘江.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/爱建.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/通江火锅.xlsx
# I m processing  /home/user/Xizhuquan_business/2021.3/高频报货/571/中央厨房.xlsx
# processing finished
